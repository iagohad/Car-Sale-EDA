# %%
import numpy as np                                                 # Implemennts milti-dimensional array and matrices
import pandas as pd                                                # For data manipulation and analysis
#!pip install seaborn matplotlib bokeh plotly pandas_profiling
import pandas_profiling
import matplotlib.pyplot as plt                                    # Plotting library for Python programming language and it's numerical mathematics extension NumPy

import seaborn as sns                                              # Provides a high level interface for drawing attractive and informative statistical graphics
# %matplotlib inline
sns.set()

from subprocess import check_output

# %%
import pandas as pd

# %%
cs_data = pd.read_csv("https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/car_sales.csv", encoding = "ISO-8859-1")

# %%
cs_data.shape
# Out:
# (9576, 10)

# %% [markdown]
# cs_data has 9576 rows and 10 columns.

# %%
cs_data.columns
# Out:
# Index(['car', 'price', 'body', 'mileage', 'engV', 'engType', 'registration',
#        'year', 'model', 'drive'],
#       dtype='object')

# %%
cs_data.head()
# Out:
#              car    price       body  mileage  engV engType registration  \
# 0           Ford  15500.0  crossover       68   2.5     Gas          yes
# 1  Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2  Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3  Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4  Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
#
#    year    model  drive
# 0  2010     Kuga   full
# 1  2011  E-Class   rear
# 2  2008   CL 550   rear
# 3  2012    B 180  front
# 4  2013  E-Class    NaN

# %%
cs_data.tail()
# Out:
#                 car    price       body  mileage  engV engType registration  \
# 9571        Hyundai  14500.0  crossover      140   2.0     Gas          yes
# 9572     Volkswagen   2200.0      vagon      150   1.6  Petrol          yes
# 9573  Mercedes-Benz  18500.0  crossover      180   3.5  Petrol          yes
# 9574          Lexus  16999.0      sedan      150   3.5     Gas          yes
# 9575           Audi  22500.0      other       71   3.6  Petrol          yes
#
#       year      model  drive
# 9571  2011     Tucson  front
# 9572  1986  Passat B2  front
# 9573  2008     ML 350   full
# 9574  2008     ES 350  front
# 9575  2007         Q7   full

# %%
cs_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9576 entries, 0 to 9575
# Data columns (total 10 columns):
# car             9576 non-null object
# price           9576 non-null float64
# body            9576 non-null object
# mileage         9576 non-null int64
# engV            9142 non-null float64
# engType         9576 non-null object
# registration    9576 non-null object
# year            9576 non-null int64
# model           9576 non-null object
# drive           9065 non-null object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 748.2+ KB

# %%
cs_data.car.unique()
# Out:
# array(['Ford', 'Mercedes-Benz', 'Nissan', 'Honda', 'Renault', 'BMW',
#        'Land Rover', 'Volkswagen', 'Audi', 'Chrysler', 'Jaguar',
#        'Mitsubishi', 'Kia', 'Porsche', 'Toyota', 'Hyundai', 'Opel',
#        'Chevrolet', 'Skoda', 'Daewoo', 'Mazda', 'Lexus', 'Infiniti',
#        'Tesla', 'Subaru', 'VAZ', 'Alfa Romeo', 'Smart', 'Peugeot',
#        'Suzuki', 'Chery', 'Bentley', 'Volvo', 'SsangYong', 'Fiat', 'ZAZ',
#        'Citroen', 'Dodge', 'Jeep', 'Great Wall', 'Seat', 'MINI', 'Dacia',
#        'Hummer', 'Geely', 'Maserati', 'BYD', 'Cadillac', 'Acura',
#        'Aston Martin', 'Rover', 'GAZ', 'GMC', 'Lincoln', 'ËUAZ',
#        'Moskvich-AZLK', 'FAW', 'UAZ', 'Rolls-Royce', 'TATA', 'ZX',
#        'Lifan', 'Mercury', 'Groz', 'Moskvich-Izh', 'Saab', 'Lancia',
#        'Aro', 'Ferrari', 'Isuzu', 'Bogdan', 'Dadi', 'Other-Retro', 'MG',
#        'Samand', 'JAC', 'Samsung', 'Lamborghini', 'Daihatsu', 'Hafei',
#        'SMA', 'Fisker', 'Changan', 'Barkas', 'Huanghai', 'Wartburg',
# ...

# %%
cs_data.car.nunique()
# Out:
# 87

# %%
cs_data.model.unique()
# Out:
# array(['Kuga', 'E-Class', 'CL 550', 'B 180', 'X-Trail', 'Accord',
#        'Megane', 'Qashqai', '316', '750', 'GLE-Class', 'M5',
#        'Range Rover', 'X5', 'Leaf', 'Passat B6', 'A6', 'Sebring', 'XF',
#        'Sprinter 324 ïàññ.', '5 Series', '520', 'Outlander', 'Juke',
#        'Galant', 'Sportage', 'Cayenne', 'Passat B5', 'Land Cruiser 200',
#        'Q7', 'Outlander XL', 'Vito ïàññ.', 'Camry', 'Panamera', 'Touareg',
#        'T5 (Transporter) ãðóç', '530', 'Accent', 'T5 (Transporter) ïàññ.',
#        'Land Cruiser Prado', 'Vectra C', 'GLS 350', 'X6', 'Q5', '318',
#        'Lacetti', 'Superb', 'Range Rover Sport', 'Passat B7', 'Lancer X',
#        'Range Rover Evoque', 'Lanos', 'Pajero Wagon', 'Vito ãðóç.',
#        'Octavia A5', '3', '6', 'LX 570', '740', 'GS 300', 'S 350', 'A5',
#        'C-Class', 'Tucson', 'Octavia A7', 'FX 37', 'GX', 'CL 55 AMG',
#        'IQ', 'Model S', 'A4', 'Forester', 'Ceed', 'Polo', '2121', 'Civic',
# ...

# %%
cs_data.model.nunique()
# Out:
# 888

# %%
duplicate_bool = cs_data.duplicated(keep='first')
cs_data_dup = cs_data.loc[duplicate_bool == True ]
print("Number of duplicates  :")
cs_data_dup.count()
#duplicate_bool
#on_duplicate = cs_data[~(cs_data.duplicated(keep='first'))]
#non_duplicate
#on_duplicate.count()
#s_data.count()


#Duplicates can be found in 2 ways
#1. data[duplicate_bool]
#2. duplicate = cs_data.loc[duplicate_bool == True]
#duplicate

#display first 20 rows
#cs_data.head(20)
# Out:
# Number of duplicates  :
# car             113
# price           113
# body            113
# mileage         113
# engV            113
# engType         113
# registration    113
# year            113
# model           113
# drive           112
# dtype: int64

# %%
cs_data_non_dup = cs_data.loc[duplicate_bool == False ]  #dropping duplicates
cs_data_non_dup.count()
# Out:
# car             9463
# price           9463
# body            9463
# mileage         9463
# engV            9029
# engType         9463
# registration    9463
# year            9463
# model           9463
# drive           8953
# dtype: int64

# %%
cs_data.describe()
# Out:
#                price      mileage         engV         year
# count    9576.000000  9576.000000  9142.000000  9576.000000
# mean    15633.317316   138.862364     2.646344  2006.605994
# std     24106.523436    98.629754     5.927699     7.067924
# min         0.000000     0.000000     0.100000  1953.000000
# 25%      4999.000000    70.000000     1.600000  2004.000000
# 50%      9200.000000   128.000000     2.000000  2008.000000
# 75%     16700.000000   194.000000     2.500000  2012.000000
# max    547800.000000   999.000000    99.990000  2016.000000

# %%
cs_data.isnull().count()
# Out:
# car             9576
# price           9576
# body            9576
# mileage         9576
# engV            9576
# engType         9576
# registration    9576
# year            9576
# model           9576
# drive           9576
# dtype: int64

# %%
profile = pandas_profiling.ProfileReport(cs_data)
profile.to_file("c:\\users\iagohad\data.html")

# %%
profile = pandas_profiling.ProfileReport(cs_data_non_dup)
profile.to_file("c:\\users\\iagohad\\data2.html")

# %%
cs_data_non_dup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9463 entries, 0 to 9575
# Data columns (total 10 columns):
# car             9463 non-null object
# price           9463 non-null float64
# body            9463 non-null object
# mileage         9463 non-null int64
# engV            9029 non-null float64
# engType         9463 non-null object
# registration    9463 non-null object
# year            9463 non-null int64
# model           9463 non-null object
# drive           8953 non-null object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 813.2+ KB

# %%
cs_data_non_dup.shape
# Out:
# (9463, 10)

# %%
cs_data_non_dup.car.nunique()
# Out:
# 87

# %%
cs_data_non_dup.model.nunique()
# Out:
# 888

# %%
cs_data_non_dup.head(10)
# Out:
#              car    price       body  mileage  engV engType registration  \
# 0           Ford  15500.0  crossover       68   2.5     Gas          yes
# 1  Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2  Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3  Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4  Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
# 5         Nissan  16600.0  crossover       83   2.0  Petrol          yes
# 6          Honda   6500.0      sedan      199   2.0  Petrol          yes
# 7        Renault  10500.0      vagon      185   1.5  Diesel          yes
# 8  Mercedes-Benz  21500.0      sedan      146   1.8     Gas          yes
# 9  Mercedes-Benz  22700.0      sedan      125   2.2  Diesel          yes
#
#    year    model  drive
# 0  2010     Kuga   full
# 1  2011  E-Class   rear
# 2  2008   CL 550   rear
# 3  2012    B 180  front
# 4  2013  E-Class    NaN
# ...

# %%
cs_data_non_dup.price.nunique()    #there are 1353 unique prices
# Out:
# 1353

# %%
cs_data_non_dup.price.isnull()   #isnull is used to find missing values. It will return false if it has value specified
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
# 30      False
#         ...
# 9546    False
# 9547    False
# 9548    False
# 9549    False
# 9550    False
# 9551    False
# 9552    False
# 9553    False
# 9554    False
# 9555    False
# 9556    False
# 9557    False
# 9558    False
# 9559    False
# 9560    False
# 9561    False
# 9562    False
# 9563    False
# 9564    False
# 9565    False
# 9566    False
# 9567    False
# 9568    False
# 9569    False
# 9570    False
# 9571    False
# 9572    False
# 9573    False
# 9574    False
# 9575    False
# ...

# %%
cs_data_non_dup.price.isna() #price doesn't have NAn values, but it does have zeros
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
# 30      False
#         ...
# 9546    False
# 9547    False
# 9548    False
# 9549    False
# 9550    False
# 9551    False
# 9552    False
# 9553    False
# 9554    False
# 9555    False
# 9556    False
# 9557    False
# 9558    False
# 9559    False
# 9560    False
# 9561    False
# 9562    False
# 9563    False
# 9564    False
# 9565    False
# 9566    False
# 9567    False
# 9568    False
# 9569    False
# 9570    False
# 9571    False
# 9572    False
# 9573    False
# 9574    False
# 9575    False
# ...

# %%
cs_data_non_dup[cs_data_non_dup.price == 0].price.count() #this gives rows which has Price column==0 values

#cs_data_non_dup[cs_data_non_dup.price == 0]   #This gives dataframe with Price column having zeros
# Out:
# 240

# %%
cs_data_non_dup[cs_data_non_dup.price != 0].price.count() #this gives rows which has Price column!=0 values
# Out:
# 9223

# %%
cs_data_non_dup[cs_data_non_dup.price == 0]
# Out:
#                 car  price       body  mileage  engV engType registration  \
# 20       Land Rover    0.0  crossover        0   4.4  Diesel          yes
# 53    Mercedes-Benz    0.0  crossover        0   3.0  Diesel          yes
# 71           Toyota    0.0  crossover        0   4.5  Diesel          yes
# 90          Porsche    0.0      sedan       22   4.8  Petrol          yes
# 92             Audi    0.0  crossover        0   3.0  Diesel          yes
# 94           Toyota    0.0  crossover       49   4.5  Diesel          yes
# 97       Volkswagen    0.0        van      165   2.0  Diesel          yes
# 102   Mercedes-Benz    0.0        van      450   2.2  Diesel          yes
# 105         Porsche    0.0  crossover        0   3.0  Diesel          yes
# 121      Volkswagen    0.0        van      162   2.0  Diesel          yes
# 124             BMW    0.0  crossover        1   3.0  Diesel          yes
# 125             BMW    0.0  crossover        0   3.0  Diesel          yes
# ...

# %%
cs_data_non_dup.price.mean()
# Out:
# 15303.858895873407

# %%
cs_data_non_dup.price.mode()   #not good idea to replace with mode, here mode is having zero value
# Out:
# 0    0.0
# dtype: float64

# %%
cs_data_non_dup.price.median()   #looks to be to low value value for 2015,2016 latest cars
# Out:
# 9200.0

# %%
df_price_zero = cs_data_non_dup[cs_data_non_dup.price == 0]   #creating DF to understand missing car models

# %%
df_price_zero.groupby(['car'])['car'].count()   #out of 240 cars Audi has more frequency of having zero price
# Out:
# car
# Audi             15
# BMW              23
# Bentley           1
# Chevrolet         3
# Chrysler          2
# Citroen           2
# Daewoo            3
# Dodge             1
# Fiat              2
# Fisker            1
# Ford              5
# GAZ               3
# GMC               1
# Honda             2
# Hyundai           4
# Kia               1
# Land Rover       12
# Lexus             4
# Mazda             5
# Mercedes-Benz    54
# Mitsubishi        4
# Nissan            2
# Opel              5
# Peugeot           2
# Porsche           9
# Renault          13
# Rolls-Royce       1
# Skoda             5
# Subaru            2
# Toyota           13
# VAZ               9
# Volkswagen       28
# ZAZ               2
# ËUAZ              1
# Name: car, dtype: int64

# %%
df_price_zero.groupby(['body'])['body'].count()  #crossover typ has more zeros in price
# Out:
# body
# crossover    78
# hatch        16
# other        26
# sedan        58
# vagon        22
# van          40
# Name: body, dtype: int64

# %%
df_price_zero[df_price_zero.body == 'crossover']
# Out:
#                 car  price       body  mileage  engV engType registration  \
# 20       Land Rover    0.0  crossover        0  4.40  Diesel          yes
# 53    Mercedes-Benz    0.0  crossover        0  3.00  Diesel          yes
# 71           Toyota    0.0  crossover        0  4.50  Diesel          yes
# 92             Audi    0.0  crossover        0  3.00  Diesel          yes
# 94           Toyota    0.0  crossover       49  4.50  Diesel          yes
# 105         Porsche    0.0  crossover        0  3.00  Diesel          yes
# 124             BMW    0.0  crossover        1  3.00  Diesel          yes
# 125             BMW    0.0  crossover        0  3.00  Diesel          yes
# 158      Land Rover    0.0  crossover       45  3.00  Petrol          yes
# 160   Mercedes-Benz    0.0  crossover        0  3.00  Diesel          yes
# 180             BMW    0.0  crossover       36  3.00  Diesel          yes
# 188   Mercedes-Benz    0.0  crossover        1  3.00  Petrol          yes
# ...

# %%
df_price_zero[(df_price_zero.body == 'crossover') & (df_price_zero.mileage == 0)] #It has been oberved that the cars where
#entred price is zero are latest/new cars so dropping them would be good idea as analysis can be done on "car operation of used cars"
# Out:
#                 car  price       body  mileage  engV engType registration  \
# 20       Land Rover    0.0  crossover        0   4.4  Diesel          yes
# 53    Mercedes-Benz    0.0  crossover        0   3.0  Diesel          yes
# 71           Toyota    0.0  crossover        0   4.5  Diesel          yes
# 92             Audi    0.0  crossover        0   3.0  Diesel          yes
# 105         Porsche    0.0  crossover        0   3.0  Diesel          yes
# 125             BMW    0.0  crossover        0   3.0  Diesel          yes
# 160   Mercedes-Benz    0.0  crossover        0   3.0  Diesel          yes
# 1104          Lexus    0.0  crossover        0   4.5  Diesel          yes
# 1699  Mercedes-Benz    0.0  crossover        0   3.0  Petrol          yes
# 2004  Mercedes-Benz    0.0  crossover        0   4.7  Petrol          yes
# 2074            BMW    0.0  crossover        0   3.0  Diesel          yes
# 2075     Land Rover    0.0  crossover        0   3.0  Diesel          yes
# ...

# %%
#Going back to non-duplicate dataframe and dropping the rows which has price=0, mileage=0  #There are 20 such entries

# %%
df_price_zero[(df_price_zero.body == 'crossover') & (df_price_zero.mileage == 0)].count()
# Out:
# car             20
# price           20
# body            20
# mileage         20
# engV            20
# engType         20
# registration    20
# year            20
# model           20
# drive           20
# dtype: int64

# %%
df_price_zero_pr_ml_0 = df_price_zero.drop(df_price_zero[(df_price_zero.body == 'crossover') & (df_price_zero.mileage == 0)].index)

# %%
df_price_zero_pr_ml_0.count()
# Out:
# car             220
# price           220
# body            220
# mileage         220
# engV            211
# engType         220
# registration    220
# year            220
# model           220
# drive           201
# dtype: int64

# %%
#Using above condition in df where duplicates are removed to get profile data

# %%
df_price_zero.car.count()
# Out:
# 240

# %%
cs_data_non_dup_pr_ml_0 = cs_data_non_dup.drop(cs_data_non_dup[(cs_data_non_dup.body == 'crossover') & (cs_data_non_dup.mileage == 0)].index)

# %%
cs_data_non_dup_pr_ml_0.car.count()
# Out:
# 9294

# %%
cs_data_non_dup.car.count()
# Out:
# 9463

# %%
profile = pandas_profiling.ProfileReport(cs_data_non_dup_pr_ml_0)
profile.to_file("c:\\users\\iagohad\\cs_data_non_dup_pr_ml_0.html")

# %%
cs_data_non_dup_pr_ml_0[cs_data_non_dup_pr_ml_0.price == 0]   #for analysis assume mean price
# Out:
#                 car  price       body  mileage  engV engType registration  \
# 90          Porsche    0.0      sedan       22   4.8  Petrol          yes
# 94           Toyota    0.0  crossover       49   4.5  Diesel          yes
# 97       Volkswagen    0.0        van      165   2.0  Diesel          yes
# 102   Mercedes-Benz    0.0        van      450   2.2  Diesel          yes
# 121      Volkswagen    0.0        van      162   2.0  Diesel          yes
# 124             BMW    0.0  crossover        1   3.0  Diesel          yes
# 158      Land Rover    0.0  crossover       45   3.0  Petrol          yes
# 180             BMW    0.0  crossover       36   3.0  Diesel          yes
# 188   Mercedes-Benz    0.0  crossover        1   3.0  Petrol          yes
# 203           Lexus    0.0  crossover       11   5.7  Petrol          yes
# 206   Mercedes-Benz    0.0      other       22   3.0  Diesel          yes
# 215   Mercedes-Benz    0.0      sedan       62   3.0  Diesel          yes
# ...

# %%
#cs_data_non_dup_pr_ml_0['price'] = cs_data_non_dup_pr_ml_0['price'].replace(0,cs_data_non_dup_pr_ml_0['price'].mean())  #replacing zero price with mean which is 14373
cs_data_non_dup_pr_ml_0.drop(cs_data_non_dup_pr_ml_0[cs_data_non_dup_pr_ml_0.price == 0].index, inplace = True)

# %%
cs_data_non_dup_pr_ml_0.car.count()
# Out:
# 9074

# %%
profile = pandas_profiling.ProfileReport(cs_data_non_dup_pr_ml_0)
profile.to_file("c:\\users\\iagohad\\cs_data_non_dup_pr_ml_0_after_pr_drop.html")  #mean (14713)did not change significatly hence taking this change

# %%
cs_data_non_dup_pr_ml_0[(cs_data_non_dup_pr_ml_0.mileage == 0)]  #most of cars which has mileage zero are latest cars
# Out:
#                 car         price   body  mileage  engV engType registration  \
# 240           Tesla  159600.00000  sedan        0   NaN   Other          yes
# 418           Mazda   25000.00000  sedan        0  2.00   Other          yes
# 460      Land Rover   79450.00000  other        0   NaN  Diesel          yes
# 504         Peugeot   17895.15000  hatch        0  1.60  Diesel          yes
# 578         Hyundai   21166.66500  sedan        0  1.80  Petrol          yes
# 637         Bentley  222222.00000  other        0  6.00  Petrol          yes
# 742         Hyundai   33500.00000  sedan        0  2.40  Petrol          yes
# 760             BMW   99999.00000  other        0  3.00  Petrol          yes
# 1055  Mercedes-Benz   47600.00000    van        0  2.20  Diesel          yes
# 1101           Audi   81500.00000  sedan        0  3.00  Petrol          yes
# 1223         Toyota   13621.43250  sedan        0  1.30  Petrol          yes
# ...

# %%
cs_data_non_dup_pr_ml_0[(cs_data_non_dup_pr_ml_0.mileage == 0)].mileage.count()
# Out:
# 134

# %%
cs_data_non_dup_pr_ml_0['mileage'] = cs_data_non_dup_pr_ml_0['mileage'].replace(0,cs_data_non_dup_pr_ml_0['mileage'].mean())  #replacing zero price with mean which is 14373
#replacing zero mileage with mean as anyway mileage data doesn't seem to be correct. We can assume that overall mileage will
#be same for same cars with similar other parameters. It is as good as not considering mileage as parameter for this dataset

# %%
cs_data_non_dup_pr_ml_0[cs_data_non_dup_pr_ml_0.drive.isna()]  #display dataframe where drive has missing value  #data doesn't reveal any significant clue
#for time being dropping it
# Out:
#                 car     price       body     mileage   engV engType  \
# 4     Mercedes-Benz  33000.00      vagon   91.000000    NaN   Other
# 37             Audi   2850.00      sedan  260.000000    NaN   Other
# 44              BMW  39333.00      sedan    6.000000   2.00  Petrol
# 52    Mercedes-Benz  31500.00      sedan  123.000000   2.20  Diesel
# 103      Volkswagen  10000.00        van  231.000000   1.90  Diesel
# 109          Nissan  12400.00      hatch   26.000000    NaN   Other
# 119   Mercedes-Benz  29500.00      sedan   37.000000   1.80  Petrol
# 154          Nissan  17700.00  crossover   40.000000   1.60  Petrol
# 163   Mercedes-Benz  17900.00        van  167.000000   2.20  Diesel
# 216         Porsche  51900.00      sedan   78.000000   4.80  Petrol
# 219          Nissan  11500.00  crossover  128.000000   2.00  Petrol
# 234   Mercedes-Benz  24999.00      sedan  112.000000   2.20  Diesel
# 254            Audi   1950.00      sedan  320.000000  19.00   Other
# ...

# %%
cs_data_non_dup_pr_ml_0.groupby(['drive'])['drive'].count()
# Out:
# drive
# front    5071
# full     2181
# rear     1334
# Name: drive, dtype: int64

# %%
cs_data_non_dup_pr_ml_0 = cs_data_non_dup_pr_ml_0.drop(cs_data_non_dup_pr_ml_0[cs_data_non_dup_pr_ml_0.drive.isna()].index)

# %%
cs_data_non_dup_pr_ml_0.count()
# Out:
# car             8586
# price           8586
# body            8586
# mileage         8586
# engV            8267
# engType         8586
# registration    8586
# year            8586
# model           8586
# drive           8586
# dtype: int64

# %%
profile = pandas_profiling.ProfileReport(cs_data_non_dup_pr_ml_0)
profile.to_file("c:\\users\\iagohad\\cs_data_non_dup_pr_ml_rpl_mean_drive_drop.html") #left with 323 missing values for engV

# %%
cs_data_non_dup_pr_ml_0[cs_data_non_dup_pr_ml_0.engV.isna()]  #if 'car model engType' should decide engV [ body  ]
# Out:
#                 car       price       body     mileage  engV engType  \
# 13              BMW    4700.000      sedan  200.000000   NaN  Petrol
# 30           Nissan   13980.000      hatch   31.000000   NaN   Other
# 31           Nissan   17300.000      hatch   24.000000   NaN   Other
# 41           Nissan   13275.000      hatch   12.000000   NaN   Other
# 56           Nissan   17000.000      hatch   38.000000   NaN   Other
# 107      Volkswagen   33500.000  crossover   98.000000   NaN  Petrol
# 150          Daewoo    3500.000      sedan  112.000000   NaN  Petrol
# 212         Hyundai   10500.000  crossover  120.000000   NaN   Other
# 231          Nissan   17000.000      hatch   20.000000   NaN   Other
# 239          Nissan   14200.000      sedan   28.000000   NaN   Other
# 240           Tesla  159600.000      sedan  143.320696   NaN   Other
# 247          Nissan   17500.000      hatch   62.000000   NaN   Other
# 259          Nissan   16500.000      hatch   32.000000   NaN   Other
# ...

# %%
cs_data_non_dup_pr_ml_0[cs_data_non_dup_pr_ml_0.registration == 'no'].count()  #There are 523 cars which are not registered in Ukraine
# Out:
# car             516
# price           516
# body            516
# mileage         516
# engV            496
# engType         516
# registration    516
# year            516
# model           516
# drive           516
# dtype: int64

# %%
cs_data_non_dup_pr_ml_0[(cs_data_non_dup_pr_ml_0.car == 'BMW') & (cs_data_non_dup_pr_ml_0.model == '316') & (cs_data_non_dup_pr_ml_0.engType == 'Petrol')] #car model engType'
#It is understood that engV depends on year of manufacturing as engine may change (Domain knowledge)
# Out:
#       car   price   body  mileage  engV engType registration  year model drive
# 13    BMW  4700.0  sedan    200.0   NaN  Petrol          yes  1996   316  rear
# 336   BMW  2550.0  sedan    280.0   1.6  Petrol           no  2000   316  rear
# 2845  BMW  1950.0  sedan    162.0   1.6  Petrol           no  1995   316  rear
# 3807  BMW  8999.0  sedan    250.0   1.9  Petrol          yes  2001   316  rear
# 5426  BMW  2600.0  sedan    250.0   1.6  Petrol          yes  1996   316  rear
# 6719  BMW  6100.0  sedan    205.0   1.8  Petrol          yes  2001   316  rear
# 9454  BMW  2200.0  sedan    290.0   1.6  Petrol          yes  1985   316  rear

# %%
 cs_data_non_dup_pr_ml_0[(cs_data_non_dup_pr_ml_0.car == 'BMW') & (cs_data_non_dup_pr_ml_0.model == '316') & (cs_data_non_dup_pr_ml_0.engType == 'Petrol') & (cs_data_non_dup_pr_ml_0.year == 1996)]
# Out:
#       car   price   body  mileage  engV engType registration  year model drive
# 13    BMW  4700.0  sedan    200.0   NaN  Petrol          yes  1996   316  rear
# 5426  BMW  2600.0  sedan    250.0   1.6  Petrol          yes  1996   316  rear

# %%
cs_data_non_dup_pr_ml_0[(cs_data_non_dup_pr_ml_0.car == 'Nissan') & (cs_data_non_dup_pr_ml_0.model == 'Leaf') & (cs_data_non_dup_pr_ml_0.year == 2013)]  #It is observed that for this particular car engV is missing as well as engType is 'other' 
#nobody wants to analyse this type of data where engType is not mentioned. dropping the rows where engType is 'other'
# Out:
#          car    price   body  mileage  engV engType registration  year model  \
# 30    Nissan  13980.0  hatch     31.0   NaN   Other          yes  2013  Leaf
# 31    Nissan  17300.0  hatch     24.0   NaN   Other          yes  2013  Leaf
# 41    Nissan  13275.0  hatch     12.0   NaN   Other          yes  2013  Leaf
# 56    Nissan  17000.0  hatch     38.0   NaN   Other          yes  2013  Leaf
# 247   Nissan  17500.0  hatch     62.0   NaN   Other          yes  2013  Leaf
# 259   Nissan  16500.0  hatch     32.0   NaN   Other          yes  2013  Leaf
# 339   Nissan  14999.0  hatch     31.0  1.00   Other          yes  2013  Leaf
# 403   Nissan  15700.0  hatch     22.0  0.11   Other          yes  2013  Leaf
# 553   Nissan  18000.0  hatch     45.0   NaN   Other          yes  2013  Leaf
# 663   Nissan  14673.0  hatch     34.0   NaN   Other          yes  2013  Leaf
# 676   Nissan  14246.0  hatch     42.0   NaN   Other          yes  2013  Leaf
# ...

# %%
cs_data_non_dup_pr_ml_0.car.count()
# Out:
# 8586

# %%
#cs_data_non_dup_pr_ml_0_drop_engTypeOt[(cs_data_non_dup_pr_ml_0_drop_engTypeOt.year == 1953)]

# %%
#cs_data_non_dup_pr_ml_0[(cs_data_non_dup_pr_ml_0.engType == 'Other')].car.count()  #343 There are 343 entries where engType is mentioned as 'Other'. Needs to drop these entries 
cs_data_non_dup_pr_ml_0_drop_engTypeOt = cs_data_non_dup_pr_ml_0.drop(cs_data_non_dup_pr_ml_0[(cs_data_non_dup_pr_ml_0.engType == 'Other')].index)

# %%
cs_data_non_dup_pr_ml_0_drop_engTypeOt.car.count()  #need to find way to change same frame as it will increase memory
# Out:
# 8248

# %%
profile = pandas_profiling.ProfileReport(cs_data_non_dup_pr_ml_0_drop_engTypeOt)
profile.to_file("c:\\users\\iagohad\\cs_data_non_dup_pr_ml_rpl_mean_drive_drop_engType_drop.html")

# %%
cs_data_non_dup_pr_ml_0_drop_engTypeOt[cs_data_non_dup_pr_ml_0_drop_engTypeOt.engV.isna()]
# Out:
#                 car    price       body  mileage  engV engType registration  \
# 13              BMW   4700.0      sedan    200.0   NaN  Petrol          yes
# 107      Volkswagen  33500.0  crossover     98.0   NaN  Petrol          yes
# 150          Daewoo   3500.0      sedan    112.0   NaN  Petrol          yes
# 273            Audi   2200.0      sedan    250.0   NaN  Diesel           no
# 275            Audi   2350.0      vagon    250.0   NaN  Diesel           no
# 276            Audi   2500.0      sedan    180.0   NaN  Petrol           no
# 363             BMW   8000.0      sedan    330.0   NaN  Diesel          yes
# 371            Audi   1300.0      sedan    250.0   NaN     Gas           no
# 524           Mazda  13500.0  crossover     69.0   NaN  Petrol          yes
# 550   Mercedes-Benz  12000.0        van    177.0   NaN  Diesel          yes
# 560             BMW  15000.0      other    205.0   NaN  Petrol          yes
# ...

# %%
cs_data_non_dup_pr_ml_0_drop_engTypeOt[cs_data_non_dup_pr_ml_0_drop_engTypeOt.model == '316' ] #Below data shows that engV is variable depends on many factors and cant be replaced easily hence dropping these rows
# Out:
#       car   price   body  mileage  engV engType registration  year model drive
# 13    BMW  4700.0  sedan    200.0   NaN  Petrol          yes  1996   316  rear
# 331   BMW  8500.0  sedan    284.0   1.9     Gas          yes  2000   316  rear
# 336   BMW  2550.0  sedan    280.0   1.6  Petrol           no  2000   316  rear
# 2845  BMW  1950.0  sedan    162.0   1.6  Petrol           no  1995   316  rear
# 3524  BMW  1550.0  sedan    300.0   NaN     Gas           no  1994   316  rear
# 3807  BMW  8999.0  sedan    250.0   1.9  Petrol          yes  2001   316  rear
# 5426  BMW  2600.0  sedan    250.0   1.6  Petrol          yes  1996   316  rear
# 6719  BMW  6100.0  sedan    205.0   1.8  Petrol          yes  2001   316  rear
# 9454  BMW  2200.0  sedan    290.0   1.6  Petrol          yes  1985   316  rear

# %%
cs_data_non_dup_pr_ml_0_drop_engTypeOt.car.count()
# Out:
# 8248

# %%
cs_data_non_dup_post_processing = cs_data_non_dup_pr_ml_0_drop_engTypeOt.drop(cs_data_non_dup_pr_ml_0_drop_engTypeOt[cs_data_non_dup_pr_ml_0_drop_engTypeOt.engV.isna()].index)

# %%
profile = pandas_profiling.ProfileReport(cs_data_non_dup_post_processing)
profile.to_file("c:\\users\\iagohad\\cs_data_non_dup_post_processing.html")

# %%
cs_data_non_dup_post_processing[cs_data_non_dup_post_processing.body == 'other'] #687 rows has 'other' in ody type
# Out:
#                 car    price   body  mileage   engV engType registration  \
# 2     Mercedes-Benz  35000.0  other    135.0   5.50  Petrol          yes
# 88    Mercedes-Benz  16500.0  other    107.0   2.20  Diesel          yes
# 146   Mercedes-Benz  43500.0  other     51.0   3.00  Diesel          yes
# 147      Volkswagen  18700.0  other    145.0   2.00  Diesel          yes
# 151             BMW  25500.0  other    163.0   4.80  Petrol          yes
# 162      Volkswagen  18900.0  other     45.0   2.00  Diesel          yes
# 173             BMW  37200.0  other    115.0   3.00  Diesel          yes
# 174      Land Rover  27500.0  other    174.0   3.60  Diesel          yes
# 200      Land Rover  30000.0  other    155.0   3.60  Diesel          yes
# 208   Mercedes-Benz   9200.0  other    280.0   2.40  Petrol          yes
# 225   Mercedes-Benz   6200.0  other    340.0   2.40     Gas          yes
# 228   Mercedes-Benz  38600.0  other     12.0   1.80  Petrol          yes
# ...

# %%
cs_data_non_dup_post_processing[cs_data_non_dup_post_processing.model == 'CL 550']
# Out:
#              car    price   body  mileage  engV engType registration  year  \
# 2  Mercedes-Benz  35000.0  other    135.0   5.5  Petrol          yes  2008
#
#     model drive
# 2  CL 550  rear

# %%
cs_data_non_dup_post_processing[cs_data_non_dup_post_processing.model == 'E-Class'] #other body type cann't be replaced 
                                                                                 #by finding matching model for same car type
                                                                                 #as can be seen with below example.
                                                                                 #body types are differnent for same model hence drop rows
# Out:
#                 car    price   body  mileage  engV engType registration  year  \
# 1     Mercedes-Benz  20500.0  sedan    173.0   1.8     Gas          yes  2011
# 8     Mercedes-Benz  21500.0  sedan    146.0   1.8     Gas          yes  2012
# 9     Mercedes-Benz  22700.0  sedan    125.0   2.2  Diesel          yes  2010
# 11    Mercedes-Benz  20400.0  sedan    190.0   1.8     Gas          yes  2011
# 12    Mercedes-Benz  22500.0  sedan    164.0   1.8     Gas          yes  2012
# 14    Mercedes-Benz  21500.0  sedan    159.0   1.8     Gas          yes  2012
# 51    Mercedes-Benz  14490.0  vagon    212.0   2.2  Diesel          yes  2008
# 110   Mercedes-Benz   6200.0  sedan    221.0   1.8     Gas          yes  2004
# 113   Mercedes-Benz  20300.0  sedan    198.0   1.8     Gas          yes  2011
# 146   Mercedes-Benz  43500.0  other     51.0   3.0  Diesel          yes  2014
# 182   Mercedes-Benz   2400.0  sedan      3.0   3.0  Diesel          yes  1998
# ...

# %%
cs_data_non_dup_post_processing_v1 = cs_data_non_dup_post_processing.drop(cs_data_non_dup_post_processing[(cs_data_non_dup_post_processing.body == 'other')].index)

# %%
profile = pandas_profiling.ProfileReport(cs_data_non_dup_post_processing_v1)
profile.to_file("c:\\users\\iagohad\\cs_data_non_dup_post_processing_v1.html")

# %%
cs_data_non_dup_post_processing_v1[(cs_data_non_dup_post_processing_v1.mileage == 1)]
# Out:
#                 car         price       body  mileage  engV engType  \
# 23              BMW   66500.00000  crossover      1.0  2.00  Diesel
# 47              BMW   63500.00000  crossover      1.0  2.00  Diesel
# 65    Mercedes-Benz  104999.00000  crossover      1.0  3.00  Diesel
# 69          Porsche   99999.00000  crossover      1.0  2.99  Diesel
# 115          Toyota   73900.00000  crossover      1.0  4.50  Diesel
# 126          Toyota   74999.00000  crossover      1.0  4.50  Diesel
# 164             BMW   67500.00000  crossover      1.0  2.00  Diesel
# 165             BMW   67500.00000  crossover      1.0  2.50  Diesel
# 204           Lexus   47000.00000  crossover      1.0  5.70  Petrol
# 217         Porsche   87900.00000  crossover      1.0  3.00  Diesel
# 253          Toyota   24171.42000      sedan      1.0  2.50  Petrol
# 342         Renault   18456.16110  crossover      1.0  1.50  Diesel
# 381   Mercedes-Benz  109999.00000  crossover      1.0  3.00  Diesel
# ...

# %%
#There is outlier in price

# %%
sns.pairplot(cs_data_non_dup_post_processing_v1, hue="year")
# Out:
# C:\Users\iagohad\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\iagohad\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\iagohad\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\iagohad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\bandwidths.py:20: RuntimeWarning: invalid value encountered in minimum
# ...

# %%
cs_data_non_dup_post_processing_v1.price.max()
# Out:
# 547800.0

# %%
cs_data_non_dup_post_processing_v1[cs_data_non_dup_post_processing_v1.price>530000]   #max price
# Out:
#           car     price   body     mileage  engV engType registration  year  \
# 7621  Bentley  547800.0  sedan  143.320696  6.75  Petrol          yes  2016
#
#          model drive
# 7621  Mulsanne  rear

# %%
cs_data_non_dup_post_processing_v1[cs_data_non_dup_post_processing_v1.model == 'Mulsanne']
# Out:
#           car     price   body     mileage  engV engType registration  year  \
# 7621  Bentley  547800.0  sedan  143.320696  6.75  Petrol          yes  2016
#
#          model drive
# 7621  Mulsanne  rear

# %%
#mean could have been affected dut to this price....Maybe dropping rows where pice=0 makes sense after deleting this outlier

# %%
cs_data_non_dup_post_processing_v1.drop(cs_data_non_dup_post_processing_v1[cs_data_non_dup_post_processing_v1.model == 'Mulsanne'].index,inplace =True)

# %%
cs_data_non_dup_post_processing_v1.car.count()
# Out:
# 7365

# %%
sns.pairplot(cs_data_non_dup_post_processing_v1, hue="year") #to check if max price is deleted

# %%
profile = pandas_profiling.ProfileReport(cs_data_non_dup_post_processing_v1)
profile.to_file("c:\\users\\iagohad\\cs_data_non_dup_post_processing_v1.html")

# %%
cs_data_non_dup_post_processing_v1.head(10)
# Out:
#               car    price       body  mileage  engV engType registration  \
# 0            Ford  15500.0  crossover     68.0   2.5     Gas          yes
# 1   Mercedes-Benz  20500.0      sedan    173.0   1.8     Gas          yes
# 3   Mercedes-Benz  17800.0        van    162.0   1.8  Diesel          yes
# 5          Nissan  16600.0  crossover     83.0   2.0  Petrol          yes
# 6           Honda   6500.0      sedan    199.0   2.0  Petrol          yes
# 7         Renault  10500.0      vagon    185.0   1.5  Diesel          yes
# 8   Mercedes-Benz  21500.0      sedan    146.0   1.8     Gas          yes
# 9   Mercedes-Benz  22700.0      sedan    125.0   2.2  Diesel          yes
# 11  Mercedes-Benz  20400.0      sedan    190.0   1.8     Gas          yes
# 12  Mercedes-Benz  22500.0      sedan    164.0   1.8     Gas          yes
#
#     year    model  drive
# 0   2010     Kuga   full
# 1   2011  E-Class   rear
# 3   2012    B 180  front
# 5   2013  X-Trail   full
# ...

# %% [markdown]
# To see relation between model used for number of years and its price

# %%
#sns.violinplot(x="model", y='price', data = df)
#sns.lmplot(x="year", y="price", hue="model", data=cs_data_non_dup_post_processing_v1)

# %%
sns.barplot(x="registration", y="price", data=cs_data_non_dup_post_processing_v1)
# Out:
# C:\Users\iagohad\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.countplot(cs_data_non_dup_post_processing_v1['body'])   #There are more sedan cars for sale than other body types

# %%
sns.countplot(cs_data_non_dup_post_processing_v1['engType']) # There are more petrol cars for sale than Gas/Diesel cars

# %%
modelwise_price_mean = cs_data_non_dup_post_processing_v1.groupby(['model','year','engType'])['price'].mean()
modelwise_price_mean
# Out:
# model            year  engType
# 1.3              1989  Petrol      1000.000000
# 10               1992  Petrol      3600.000000
# 100              1986  Diesel      3500.000000
#                  1987  Gas         2500.000000
#                  1989  Diesel      2400.000000
#                        Gas         2650.000000
#                  1991  Gas         4149.500000
#                        Petrol      4075.000000
#                  1992  Gas         4700.000000
#                        Petrol      4266.666667
#                  1993  Gas         3990.000000
#                        Petrol      4800.000000
# 106              1993  Petrol      1900.000000
# 107              2012  Petrol      7903.907143
#                  2013  Petrol      8166.666667
#                  2014  Petrol      9300.000000
# 11               1988  Gas         1800.000000
# 1102 Òàâðèÿ      1992  Gas          643.000000
#                        Petrol       785.000000
# ...

# %%
cs_data_non_dup_post_processing_v1[(cs_data_non_dup_post_processing_v1.model == '100')]
# Out:
#        car   price   body  mileage  engV engType registration  year model  \
# 1473  Audi  5000.0  sedan    280.0   2.3     Gas          yes  1992   100
# 3704  Audi  3990.0  sedan    413.0   2.6     Gas          yes  1993   100
# 3722  Audi  4000.0  sedan    400.0   2.0  Petrol          yes  1992   100
# 3723  Audi  2900.0  sedan      1.0   2.3     Gas          yes  1989   100
# 4070  Audi  3150.0  sedan     10.0   2.8  Petrol          yes  1991   100
# 4265  Audi  4800.0  sedan    341.0   2.8  Petrol          yes  1992   100
# 4688  Audi  3500.0  sedan    265.0   2.0  Diesel          yes  1986   100
# 4712  Audi  4299.0  sedan    307.0   2.8     Gas          yes  1991   100
# 5297  Audi  4000.0  sedan    320.0   2.8  Petrol          yes  1992   100
# 5398  Audi  2500.0  sedan    371.0   2.2     Gas          yes  1987   100
# 5830  Audi  2400.0  sedan    305.0   2.3     Gas          yes  1989   100
# 6000  Audi  2400.0  sedan    310.0   2.0  Diesel          yes  1989   100
# ...

# %%
cs_data_e_class = cs_data_non_dup_post_processing_v1[(cs_data_non_dup_post_processing_v1.model == 'E-Class')]
cs_data_e_class
# Out:
#                 car    price   body  mileage  engV engType registration  year  \
# 1     Mercedes-Benz  20500.0  sedan    173.0   1.8     Gas          yes  2011
# 8     Mercedes-Benz  21500.0  sedan    146.0   1.8     Gas          yes  2012
# 9     Mercedes-Benz  22700.0  sedan    125.0   2.2  Diesel          yes  2010
# 11    Mercedes-Benz  20400.0  sedan    190.0   1.8     Gas          yes  2011
# 12    Mercedes-Benz  22500.0  sedan    164.0   1.8     Gas          yes  2012
# 14    Mercedes-Benz  21500.0  sedan    159.0   1.8     Gas          yes  2012
# 51    Mercedes-Benz  14490.0  vagon    212.0   2.2  Diesel          yes  2008
# 110   Mercedes-Benz   6200.0  sedan    221.0   1.8     Gas          yes  2004
# 113   Mercedes-Benz  20300.0  sedan    198.0   1.8     Gas          yes  2011
# 182   Mercedes-Benz   2400.0  sedan      3.0   3.0  Diesel          yes  1998
# 343   Mercedes-Benz   8200.0  sedan    280.0   2.4     Gas          yes  1997
# ...

# %%
cs_data_e_class_new = cs_data_e_class.groupby(['model','year','engType'])['price'].sum()
cs_data_e_class_new
# Out:
# model    year  engType
# E-Class  1978  Gas          2300.0
#                Petrol       5500.0
#          1985  Gas          3200.0
#          1986  Diesel       2700.0
#          1989  Diesel       5250.0
#          1991  Diesel       1600.0
#                Petrol      10800.0
#          1992  Diesel       6550.0
#                Gas          5000.0
#          1993  Gas          4900.0
#          1994  Diesel      12000.0
#                Gas         11500.0
#                Petrol      18500.0
#          1995  Diesel       5300.0
#                Gas          8150.0
#                Petrol      10799.0
#          1996  Diesel       2000.0
#                Gas          5000.0
#                Petrol       6900.0
#          1997  Diesel      19050.0
#                Gas          8200.0
#                Petrol      19399.0
#          1998  Diesel       6500.0
#                Gas         14990.0
#          1999  Diesel      25999.0
#                Gas          6500.0
# ...

# %%
sns.catplot(x="year", y="price", hue="engType", data=cs_data_e_class, kind="swarm", height=4, aspect=3.5)  #for e-class           #sale of Diesel than gas, diesel

# %%
cs_data_e_class_new = cs_data_e_class.groupby(['engType'])['price'].sum() #Diesel cars sales are creating approx double revenue as compared to gas/petrol cars
cs_data_e_class_new
# Out:
# engType
# Diesel    1082885.0
# Gas        388039.0
# Petrol     311148.0
# Name: price, dtype: float64

# %%
cs_data_e_class_new = cs_data_e_class.groupby(['engType'])['price'].count()   #no of diesel cars for sale are also double in number
cs_data_e_class_new
# Out:
# engType
# Diesel    87
# Gas       36
# Petrol    31
# Name: price, dtype: int64

# %%
sns.catplot(x="year", y="price", hue="engType", data=cs_data_e_class, kind="swarm", height=4, aspect=3.5)

# %% [markdown]
# Sale analysis of A6 cars

# %%
cs_data_a6 = cs_data_non_dup_post_processing_v1[(cs_data_non_dup_post_processing_v1.model == 'A6')]
cs_data_a6
# Out:
#        car    price   body     mileage   engV engType registration  year  \
# 33    Audi   2600.0  vagon  273.000000   2.50  Diesel           no  1999
# 38    Audi  37000.0  sedan   37.000000   2.80  Petrol          yes  2012
# 40    Audi   3850.0  vagon  215.000000   2.50  Diesel           no  2002
# 55    Audi   3650.0  sedan  240.000000   2.50  Diesel           no  2000
# 184   Audi   4600.0  vagon  242.000000  99.99  Diesel           no  2004
# 209   Audi   6800.0  sedan  225.000000   2.40     Gas          yes  1998
# 260   Audi  25500.0  sedan  140.000000   2.80  Petrol          yes  2012
# 274   Audi   2300.0  vagon  250.000000   2.50  Diesel           no  2001
# 289   Audi   3700.0  vagon  273.000000   2.50  Diesel           no  2003
# 514   Audi   4850.0  sedan  270.000000   2.60  Petrol          yes  1995
# 585   Audi  20500.0  sedan  155.000000   3.00  Petrol          yes  2010
# 591   Audi   2650.0  vagon  270.000000   2.50  Diesel           no  2001
# ...

# %%
cs_data_a6_new = cs_data_a6.groupby(['model','year','engType'])['price'].sum()
cs_data_a6_new
# Out:
# model  year  engType
# A6     1995  Petrol       4850.0
#        1996  Diesel      16700.0
#              Petrol       4700.0
#        1997  Diesel      13600.0
#              Gas         12900.0
#              Petrol       4000.0
#        1998  Diesel      17749.0
#              Gas         18300.0
#              Petrol      14600.0
#        1999  Diesel      30099.0
#              Gas         18200.0
#              Petrol       6500.0
#        2000  Diesel      48399.0
#              Gas          6400.0
#              Petrol       9300.0
#        2001  Diesel      36900.0
#              Petrol       8600.0
#        2002  Diesel      59738.0
#        2003  Diesel      86999.0
#              Gas         15899.0
#        2004  Diesel      41350.0
#        2005  Diesel      58150.0
#              Gas         11900.0
#              Petrol      24400.0
#        2006  Diesel      52800.0
#              Petrol      63950.0
#        2007  Diesel      30999.0
# ...

# %%
sns.catplot(x="year", y="price", hue="engType", data=cs_data_a6, kind="swarm", height=4, aspect=3.5)  #for a6,older A6 cars (1998-2003) are more in number for sales as compared to recent production years

# %%
cs_data_a6_new = cs_data_a6.groupby(['mileage','year','engType'])['mileage'].mean()
cs_data_a6_new
# Out:
# mileage     year  engType
# 1.000000    1998  Diesel       1.000000
# 25.000000   1999  Diesel      25.000000
# 37.000000   2012  Petrol      37.000000
# 54.000000   2011  Petrol      54.000000
# 61.000000   2012  Petrol      61.000000
# 71.000000   2012  Petrol      71.000000
# 80.000000   2013  Petrol      80.000000
# 92.000000   2013  Petrol      92.000000
# 103.000000  2013  Diesel     103.000000
# 104.000000  2010  Petrol     104.000000
# 105.000000  2012  Petrol     105.000000
#             2014  Diesel     105.000000
# 108.000000  2013  Diesel     108.000000
# 110.000000  2002  Diesel     110.000000
#             2011  Petrol     110.000000
# 122.000000  2011  Petrol     122.000000
# 125.000000  2009  Diesel     125.000000
# 127.000000  2010  Petrol     127.000000
# 130.000000  2006  Petrol     130.000000
# 136.000000  2007  Petrol     136.000000
#             2009  Diesel     136.000000
# 140.000000  2012  Diesel     140.000000
#                   Petrol     140.000000
# ...

# %%
sns.catplot(x="year", y="mileage", hue="engType", data=cs_data_a6, kind="swarm", height=4, aspect=3.5) #In recent years the cars for sale are with less mileage for A6

# %%
sns.catplot(x="year", y="mileage", hue="engType", data=cs_data_non_dup_post_processing_v1, kind="swarm", height=5, aspect=3.5)  #In recent year car sales cars with less mileage are being 
#manufactured as people refer engine power than price mileage above 600 looks to be in less quantity

# %%
sns.catplot(x="price", y="year", hue="engType", data=cs_data_non_dup_post_processing_v1, kind="swarm", height=5, aspect=3.5)  #In recent year car sales cars with less mileage are being 
#manufactured as people refer engine power than price mileage above 600 looks to be in less quantity

# %%
#Available price range was less from 1960 until 2000. Price range has varying widely post year 2000. It means all segments of society has
#feasibility of buying cars. This is even better post year 2010.

# %%
cs_data_non_dup_post_processing_v1[((cs_data_non_dup_post_processing_v1.year > 1960) & (cs_data_non_dup_post_processing_v1.year < 1970))]
# Out:
#                 car    price   body  mileage  engV engType registration  year  \
# 4165            GAZ  15000.0  sedan      1.0  12.0  Petrol          yes  1962
# 4737            GAZ  15000.0  sedan     40.0   2.5  Petrol          yes  1963
# 7625  Moskvich-AZLK   1500.0  hatch      1.0   1.4  Petrol          yes  1964
# 8727            GAZ   2000.0  sedan     70.0  70.0  Petrol          yes  1968
#
#      model drive
# 4165    21  rear
# 4737    21  rear
# 7625   403  rear
# 8727    21  rear

# %%
#Above Data shows that there is lot of price difference between price for same model. Even though engine power is 
#more for 8727 row car model 21 (GAZ car) price quoted is much less than row 4165 price. Ratio is 7.5 times which is too high.

# %%
cs_data_non_dup_post_processing_v1[cs_data_non_dup_post_processing_v1.model == "21"]
# Out:
#           car    price   body  mileage  engV engType registration  year model  \
# 4165      GAZ  15000.0  sedan      1.0  12.0  Petrol          yes  1962    21
# 4737      GAZ  15000.0  sedan     40.0   2.5  Petrol          yes  1963    21
# 6349      GAZ   4000.0  sedan     98.0   2.4  Petrol          yes  1970    21
# 8727      GAZ   2000.0  sedan     70.0  70.0  Petrol          yes  1968    21
# 8996  Renault   1350.0  sedan    100.0   1.7  Petrol          yes  1986    21
#
#       drive
# 4165   rear
# 4737   rear
# 6349   rear
# 8727   rear
# 8996  front

# %% [markdown]
# Comparing the above  data it is surprizing results when it comes to price for same drive,model,engType,body

# %%
cs_data_a6_new = cs_data_a6.groupby(['mileage','year','engType'])['mileage'].mean()

# %%
cs_data_non_dup_post_processing_v1.groupby(['engType'])['price'].sum()
# Out:
# engType
# Diesel    3.993674e+07
# Gas       1.455553e+07
# Petrol    5.002390e+07
# Name: price, dtype: float64

# %%
mileage_1 = cs_data_non_dup_post_processing_v1[(cs_data_non_dup_post_processing_v1.mileage == 1)]

# %%
cs_data_non_dup_post_processing_v1[(cs_data_non_dup_post_processing_v1.mileage == 1) & (cs_data_non_dup_post_processing_v1.body == 'crossover')]
# Out:
#                 car         price       body  mileage  engV engType  \
# 23              BMW   66500.00000  crossover      1.0  2.00  Diesel
# 47              BMW   63500.00000  crossover      1.0  2.00  Diesel
# 65    Mercedes-Benz  104999.00000  crossover      1.0  3.00  Diesel
# 69          Porsche   99999.00000  crossover      1.0  2.99  Diesel
# 115          Toyota   73900.00000  crossover      1.0  4.50  Diesel
# 126          Toyota   74999.00000  crossover      1.0  4.50  Diesel
# 164             BMW   67500.00000  crossover      1.0  2.00  Diesel
# 165             BMW   67500.00000  crossover      1.0  2.50  Diesel
# 204           Lexus   47000.00000  crossover      1.0  5.70  Petrol
# 217         Porsche   87900.00000  crossover      1.0  3.00  Diesel
# 342         Renault   18456.16110  crossover      1.0  1.50  Diesel
# 381   Mercedes-Benz  109999.00000  crossover      1.0  3.00  Diesel
# 479          Toyota   20859.15000  crossover      1.0  2.00  Petrol
# ...

# %%
type_and_price = cs_data_non_dup_post_processing_v1.groupby('body').price.sum().reset_index()
type_and_count = cs_data_non_dup_post_processing_v1.groupby('body').price.count().reset_index()
#changing column heading; by default it comes as price
names = type_and_count.columns.tolist()
names[names.index('price')] = 'count'
type_and_count.columns = names

names = type_and_count.columns.tolist()
names[names.index('body')] = 'dup'
type_and_count.columns = names
#Crossover body type cars on toplist when it comes to revenue from entire car body types. Also sedan count for sale is double
#as compared to crossover market. Car sale is maket of crossover and sedan. Need to check what is demand 
#
#type_and_price
#type_and_count
body_price_count= pd.concat([type_and_price, type_and_count], axis=1) 
body_price_count.drop('dup', axis = 1,inplace = True)
body_price_count
# Out:
#         body         price  count
# 0  crossover  4.396690e+07   1649
# 1      hatch  8.143290e+06   1032
# 2      sedan  3.686105e+07   3145
# 3      vagon  5.662539e+06    629
# 4        van  9.882380e+06    910

# %%
sns.factorplot(data = body_price_count, x='body', y='price', size=6).set_index('Plot of Price Vs Body type count')
# Out:
# C:\Users\iagohad\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\iagohad\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.factorplot(data = body_price_count, x='body', y='count', size=6)
# Out:
# C:\Users\iagohad\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\iagohad\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
body_price_count
body_price_count.plot.bar(stacked=True)

# %%
sns.violinplot('body','price', kind='point', data =  cs_data_non_dup_post_processing_v1)

# %%
sns.countplot(cs_data_non_dup_post_processing_v1['engType'])

# %%
cs_data_non_dup_post_processing_v1.groupby('body').count()
# Out:
#             car  price  mileage  engV  engType  registration  year  model  \
# body
# crossover  1649   1649     1649  1649     1649          1649  1649   1649
# hatch      1032   1032     1032  1032     1032          1032  1032   1032
# sedan      3145   3145     3145  3145     3145          3145  3145   3145
# vagon       629    629      629   629      629           629   629    629
# van         910    910      910   910      910           910   910    910
#
#            drive
# body
# crossover   1649
# hatch       1032
# sedan       3145
# vagon        629
# van          910

# %%
sns.catplot(x="engV", y="price", hue="engType", data=cs_data_non_dup_post_processing_v1, kind="swarm", height=4, aspect=3,legend=True,margin_titles = True)

# %%
cs_data_non_dup_post_processing_v1[(cs_data_non_dup_post_processing_v1.price > 150000) & (cs_data_non_dup_post_processing_v1.engV > 3.2)]
#List of Expensive cars which has relatively less engine power.
# Out:
#                 car     price       body     mileage  engV engType  \
# 39    Mercedes-Benz  200000.0        van   19.000000   3.5  Petrol
# 857      Land Rover  164999.0  crossover    1.000000   4.4  Diesel
# 1004     Land Rover  168000.0  crossover    6.000000   4.4  Diesel
# 1478        Bentley  259000.0      sedan  143.320696   6.0  Petrol
# 1891  Mercedes-Benz  295000.0      sedan   29.000000   6.0  Petrol
# 2165  Mercedes-Benz  295000.0      sedan   29.000000   6.0  Petrol
# 2186     Land Rover  162000.0  crossover   21.000000   4.4  Diesel
# 2343  Mercedes-Benz  219900.0  crossover   30.000000   6.3  Petrol
# 2790  Mercedes-Benz  195000.0  crossover    2.000000   5.5  Petrol
# 3433     Land Rover  153000.0  crossover   15.000000   4.4  Diesel
# 3909  Mercedes-Benz  219900.0  crossover   33.000000   5.5  Petrol
#
#      registration  year               model drive
# 39            yes  2013  Sprinter 324 ïàññ.  rear
# 857           yes  2016         Range Rover  full
# ...

# %%
cs_data_non_dup_post_processing_v1[(cs_data_non_dup_post_processing_v1.model == "S 600")]
# Out:
#                 car     price   body  mileage  engV engType registration  \
# 1748  Mercedes-Benz   11200.0  sedan    198.0   6.0  Petrol          yes
# 1891  Mercedes-Benz  295000.0  sedan     29.0   6.0  Petrol          yes
#
#       year  model drive
# 1748  2004  S 600  rear
# 1891  2011  S 600  rear

# %%
cs_data_non_dup_post_processing_v1[(cs_data_non_dup_post_processing_v1.model == "S-Guard")]
# Out:
#                 car     price   body  mileage  engV engType registration  \
# 2165  Mercedes-Benz  295000.0  sedan     29.0   6.0  Petrol          yes
#
#       year    model drive
# 2165  2011  S-Guard  rear

# %%
cs_data_non_dup_post_processing_v1[(cs_data_non_dup_post_processing_v1.year <= 1980)]
# Out:
#                 car      price       body  mileage   engV engType  \
# 1068            VAZ   2600.000      sedan    120.0   1.70     Gas
# 2623            VAZ   2000.000      sedan     49.0   1.30  Petrol
# 3416            VAZ   2800.000      sedan      2.0   1.20  Petrol
# 3583            VAZ   1500.000      sedan     50.0   1.45     Gas
# 3612            VAZ    800.000      sedan     25.0   1.30  Petrol
# 3915            VAZ   2900.000  crossover      1.0   1.60  Petrol
# 3956            VAZ   1000.000      sedan    200.0   1.60  Petrol
# 3985         Toyota    600.000      sedan     10.0   1.50  Petrol
# 4165            GAZ  15000.000      sedan      1.0  12.00  Petrol
# 4737            GAZ  15000.000      sedan     40.0   2.50  Petrol
# 4842            VAZ   2200.000      sedan    125.0   1.30     Gas
# 4866            VAZ   2700.000  crossover     96.0   1.60  Petrol
# 4921            UAZ   8000.000  crossover      1.0   2.50  Petrol
# ...
